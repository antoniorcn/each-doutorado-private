# %%
import numpy as np

# %%
def relu( valor : np.ndarray ):
    return np.maximum(valor, np.zeros_like(valor))

def sigmoid( valor : np.ndarray):
    return  1 / (1 + np.exp(-valor))

# %%
# Definir tamanhos
N = 5 # numero de instancias
ne =  # numero de features
ns = 2 # Numero de classes de saida
h = 4 # Numero de neuronios na camada escondida

# %%
X = np.zeros( (N, ne + 1) )
Yd = np.zeros( (N, ns))
print("X.shape => ", X.shape)
print("Yd.shape => ", Yd.shape)
# Out:
# X.shape =>  (5, 2)
# Yd.shape =>  (5, 2)

# %%
# Calcular pesos
A = np.random.randint(-2, 2, ne + 1) * 0.10
B = np.random.randint(-2, 2, ne + 1) * 0.10
print("A: ", A)
print("B: ", B)
# Out:
# A:  [ 0.  -0.2]
# B:  [-0.1 -0.1]

# %%
AT = np.array([A]).T
BT = np.array([B]).T
print("A.T => ", AT)
print("B.T => ", BT)
# Out:
# A.T =>  [[ 0. ]
#  [-0.2]]
# B.T =>  [[-0.1]
#  [-0.1]]

# %%
# Calcular a saida
print("X Shape => ", X.shape)
print("A.T Shape => ", AT.shape)
Zin = X @ AT
print("Zin => ", Zin)
Z = np.array(relu( Zin ))
print("Z Shape => ", Z.shape)
print("Z.T Shape => ", Z.T.shape)
print("B.T Shape => ", BT.shape)
Yin = Z @ BT
Y = sigmoid( Yin )
print("Y: ", Y)
# Out:
# X Shape =>  (5, 2)
# A.T Shape =>  (2, 1)
# Zin =>  [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]
# Z Shape =>  (5, 1)
# Z.T Shape =>  (1, 5)
# B.T Shape =>  (2, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 10
#       8 print("Z.T Shape => ", Z.T.shape)
#       9 print("B.T Shape => ", BT.shape)
# ---> 10 Yin = Z @ BT
#      11 Y = sigmoid( Yin )
#      12 print("Y: ", Y)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)

# %%
fl = (1-Z) * Z
gl = (1-Y) * Y
gl
# Out:
# array([[0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25],
#        [0.25, 0.25, 0.25]])

# %%
erro = Y - Yd
erro
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 erro = Y - Yd
#       2 erro
#
# ValueError: operands could not be broadcast together with shapes (10,3) (10,2)
