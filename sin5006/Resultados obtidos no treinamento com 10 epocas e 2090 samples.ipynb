# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
accuracy = [0.7272727489471436, 0.7272727489471436, 0.7272727489471436, 0.7272727489471436, 0.7296651005744934, 0.7755981087684631, 0.8153110146522522, 0.8387559652328491, 0.8674641251564026, 0.8703349232673645]
loss = [0.6176278591156006, 0.5985803008079529, 0.5897036194801331, 0.5748831033706665, 0.5321992039680481, 0.45981788635253906, 0.3917822539806366, 0.354075163602829, 0.3127123713493347, 0.28409337997436523]
hter = [0.6013, 0.5547, 0.5034, 0.1991, 0.1931, 0.1043, 0.1241, 0.1974, 0.1185, 0.0836]

# %%
plt.plot(accuracy, color="blue", label="Acurácia")
plt.plot(loss, color="red", label="Perda")
plt.plot(hter, color="green", label="HTER e EER")
plt.xlabel('Épocas') # Label the x-axis
plt.title('Treinamento da rede Face Spoofing com') # Add a title
plt.legend()
plt.show()
